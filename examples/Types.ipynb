# %%
import sys
sys.path.append(r"../AutoPyro")

# %%
sys.path
# Out:
# ['d:\\Code\\Python\\AutoPyro Project\\examples',
#  'g:\\miniconda3\\envs\\ap\\python311.zip',
#  'g:\\miniconda3\\envs\\ap\\DLLs',
#  'g:\\miniconda3\\envs\\ap\\Lib',
#  'g:\\miniconda3\\envs\\ap',
#  '',
#  'g:\\miniconda3\\envs\\ap\\Lib\\site-packages',
#  'g:\\miniconda3\\envs\\ap\\Lib\\site-packages\\win32',
#  'g:\\miniconda3\\envs\\ap\\Lib\\site-packages\\win32\\lib',
#  'g:\\miniconda3\\envs\\ap\\Lib\\site-packages\\Pythonwin',
#  '../AutoPyro']

# %%
import os


os.getcwd()
# Out:
# 'd:\\Code\\Python\\AutoPyro Project\\examples'

# %%
from AutoPyro.core import geometries
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from AutoPyro.core import geometries
#
# ModuleNotFoundError: No module named 'AutoPyro'

# %%
geometries.Labels()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 geometries.Labels()
#
# NameError: name 'geometries' is not defined

# %%
geometries.LabelPoint(1, 1,{})

# %%
geometries.LabelArea(((0, 0), (0, 1), (1, 1), (1, 0)), {})

# %%
geometries.LabelCurve()
